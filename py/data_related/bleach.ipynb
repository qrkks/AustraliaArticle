# %%
import pandas as pd

# %%
df = pd.read_csv('../../db/purged/data.csv',index_col='序号')
df.head()
# Out:
#     经济毒性分级  经济健康总分  性别  居住地  医疗费用承担方式  治疗方式  有无远处转移  改变生活方式  不得不动用储蓄  使用信用卡贷款  \
# 序号
# 1        2       8   1    1         1     2       1       1        1        0
# 2        2      10   2    2         1     2       0       1        1        0
# 3        2      15   1    2         1     2       1       1        1        0
# 4        2       8   2    1         1     1       0       1        1        0
# 5        0      27   1    2         2     2       0       0        0        0
#
#     ...  生活状况（PWB）  社会/家庭状况（SWB）  情感状况（EWB）  功能状态（FWB）  肺癌相关症状（LCS）  心理弹性总分  \
# 序号  ...
# 1   ...         13            17          8         16           16      19
# 2   ...         21            21         12         13           18      24
# 3   ...          2            22          6         26           20      32
# 4   ...         15            15         10          4           21       9
# 5   ...          5            14          5         12           14      27
#
# ...

# %%
df.columns
# Out:
# Index(['经济毒性分级', '经济健康总分', '性别', '居住地', '医疗费用承担方式', '治疗方式', '有无远处转移', '改变生活方式',
#        '不得不动用储蓄', '使用信用卡贷款', '增加工作时间', '放弃休闲娱乐', '减少生活必需品的消费', '改变医疗计划',
#        '担心费用而推迟医疗服务', '经济相关服药不依从', '向他人寻求帮助', '向亲戚朋友借钱', '寻求慈善机构或公共援助',
#        '其他类型的医疗救助', '大病救助', '民政救助', '申请免费药物', '失独费用', '退伍军人，报销', '商业保险类型',
#        '未购买原因', '支付不起', '不了解相关信息', '买过但感觉被骗了', '认为没必要', '买过但过期了', '文化程度', '职业',
#        '目前就业状况', '报销比例', '你的月收入', '家庭每月人均收入', '患病类型', '病情分期', '年龄', '住院数',
#        '住院时间（天数）', '医院总费用', '其中自付费用', '外购药费用', '食宿费（元/天）', '食宿费总计',
#        '交通费用（元/次）', '交通费用总计', '营养费（共计）', '客观支持', '主观支持', '对支持的利用度', '社会支持总分',
#        '生活状况（PWB）', '社会/家庭状况（SWB）', '情感状况（EWB）', '功能状态（FWB）', '肺癌相关症状（LCS）',
#        '心理弹性总分', '家庭沟通和问题解决（FCPS）', '利用社会资源（USR）', '保持积极的前景（MPO）', '家庭弹性总分'],
#       dtype='object')

# %%
df_related = df[
    ['经济毒性分级', '经济健康总分', '客观支持', '主观支持', '社会支持总分', '生活状况（PWB）', '情感状况（EWB）', '功能状态（FWB）', '利用社会资源（USR）']
]
df_related.head()
# Out:
#     经济毒性分级  经济健康总分  客观支持  主观支持  社会支持总分  生活状况（PWB）  情感状况（EWB）  功能状态（FWB）  \
# 序号
# 1        2       8     7    13      24         13          8         16
# 2        2      10     3    11      22         21         12         13
# 3        2      15     8    26      38          2          6         26
# 4        2       8     6    11      20         15         10          4
# 5        0      27     7    12      22          5          5         12
#
#     利用社会资源（USR）
# 序号
# 1             6
# 2            11
# 3             6
# 4            12
# 5             8

# %%
df_related.to_csv('../../db/filtered/data_related.csv',encoding='utf-8-sig')
